# %%
from gan import GAN
from Models import discriminiator, generator
from Datas import data_loader
import tensorflow as tf

# %%
def workflow():
    epochs = 5000
    x_pixels = 32
    y_pixels = 32
    num_examples_to_generate = 16
    seed = 2022
    batch_size = 32

    #data_dir = "C:/Users/emeri/data/DogImages"
    data_dir = "C:/Users/emeri/data/HandWriting"

    train_dataset, val_dataset = data_loader.load_image_dir_dataset(data_dir, x_pixels, y_pixels)

    model_gen = generator.get_model_generator(x_pixels, y_pixels)
    model_disc = discriminiator.get_model_discriminator(x_pixels, y_pixels)

    gan = GAN()

    gan.set_training_hyper_params(epochs, num_examples_to_generate, x_pixels, y_pixels, batch_size, seed)
    
    gan.set_images_dataset(train_dataset, val_dataset)
    
    gan.set_discriminator_model(model_disc)
    gan.set_generator_model(model_gen)

    gan.train()

# %% [markdown]
# # Model Generator Plot

# %%
tf.keras.utils.plot_model(generator.get_model_generator(32, 32), show_shapes=True)

# %% [markdown]
# # Model Discriminator Plot

# %%
tf.keras.utils.plot_model(discriminiator.get_model_discriminator(32, 32), show_shapes=True)

# %%
workflow()
# Out:
# <dtype: 'float32'>
# -----> Loss generator : tf.Tensor(29.618341, shape=(), dtype=float32)
# -----> 10 Fake disc pred :  tf.Tensor(
# [[1.3642502e-13]
#  [1.3642502e-13]
#  [1.3642502e-13]
#  [1.3642502e-13]
#  [1.3642502e-13]
#  [1.3642502e-13]
#  [1.3642502e-13]
#  [1.3642502e-13]
#  [1.3642502e-13]
#  [1.3642502e-13]], shape=(10, 1), dtype=float32)
# Time for epoch 262 is 16.275047779083252 sec
